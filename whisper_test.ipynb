# %%
# Importing Wisper
import whisper

import os

import datetime # to track how long this takes

import librosa 

starttime=datetime.datetime.now()
print(''.join(["Start time is",str(starttime)]))


# model details
runthismodel="small" # tried base.en. It seems to recognize it as a model BUT doesn't want to do the language detection or decoding options steps.
melsforthismodel=128 #need 128 for large model, 80 for smaller ones

# stimulus set: set "folder/" that contains sound files you want to do ASR on
soundfolder="/home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper"  ###"audiofiles/VRVT/mels100x34reg/"
# Out:
# Start time is2025-04-18 12:47:11.212502

# %%
# Loading the Model
model = whisper.load_model(runthismodel) #("base") # let's see how "large" model does SC 12/27/23

# %%
for file_name in os.listdir(soundfolder):
    print(file_name)
    if file_name.endswith('.wav'):
        file_path = os.path.join(soundfolder, file_name)
        print(file_path)
        

        result = model.transcribe("file_path")
        print(result["text"])
# Out:
# L2d20speaker1_ten.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d20speaker1_ten.wav
# Error loading file
# L2d38speaker1_waist.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d38speaker1_waist.wav
# Error loading file
# L2d17speaker1_nod.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d17speaker1_nod.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d47speakerA_card.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d47speakerA_card.wav
# Error loading file
# L2d1speaker1_eyes.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d1speaker1_eyes.wav
# Error loading file
# L2d53speakerA_west.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d53speakerA_west.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d2speakerA_pan.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d2speakerA_pan.wav
# Error loading file
# L2d11speakerA_waist.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d11speakerA_waist.wav
# Error loading file
# L2d36speaker1_x.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d36speaker1_x.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d27speaker1_whale.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d27speaker1_whale.wav
# Error loading file
# L2d51speaker1_cart.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d51speaker1_cart.wav
# Error loading file
# L2d24speaker1_card.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d24speaker1_card.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d25speaker1_coat.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d25speaker1_coat.wav
# Error loading file
# L2d36speakerA_code.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d36speakerA_code.wav
# Error loading file
# L2d42speaker1_well.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d42speaker1_well.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d25speaker1_seed.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d25speaker1_seed.wav
# Error loading file
# L2d7speakerA_card.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d7speakerA_card.wav
# Error loading file
# L2d11speakerA_pen.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d11speakerA_pen.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d57speakerA_coat.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d57speakerA_coat.wav
# Error loading file
# L2d58speakerA_waist.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d58speakerA_waist.wav
# Error loading file
# L2d27speakerA_whale.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d27speakerA_whale.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d15speakerA_x.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d15speakerA_x.wav
# Error loading file
# L2d24speaker1_band.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d24speaker1_band.wav
# Error loading file
# L2d19speakerA_knot.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d19speakerA_knot.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d57speaker1_ship.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d57speaker1_ship.wav
# Error loading file
# L2d42speakerA_can.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d42speakerA_can.wav
# Error loading file
# L2d17speakerA_log.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d17speakerA_log.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d58speakerA_whale.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d58speakerA_whale.wav
# Error loading file
# L2d52speaker1_card.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d52speaker1_card.wav
# Error loading file
# L2d48speakerA_jam.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d48speakerA_jam.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d7speaker1_log.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d7speaker1_log.wav
# Error loading file
# L2d48speakerA_cart.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d48speakerA_cart.wav
# Error loading file
# L2d3speaker1_tan.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d3speaker1_tan.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d28speaker1_eggs.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d28speaker1_eggs.wav
# Error loading file
# L2d49speaker1_banana.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d49speaker1_banana.wav
# Error loading file
# L2d31speaker1_can.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d31speaker1_can.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d59speakerA_pan.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d59speakerA_pan.wav
# Error loading file
# L2d16speaker1_kick.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d16speaker1_kick.wav
# Error loading file
# L2d15speaker1_bag.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d15speaker1_bag.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d45speakerA_cart.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d45speakerA_cart.wav
# Error loading file
# L2d55speaker1_coat.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d55speaker1_coat.wav
# Error loading file
# L2d28speakerA_whale.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d28speakerA_whale.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d18speaker1_peas.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d18speaker1_peas.wav
# Error loading file
# L2d40speakerA_gem.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d40speakerA_gem.wav
# Error loading file
# L2d45speakerA_ship.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d45speakerA_ship.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d18speaker1_kick.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d18speaker1_kick.wav
# Error loading file
# L2d9speakerA_kick.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d9speakerA_kick.wav
# Error loading file
# L2d2speakerA_knot.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d2speakerA_knot.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d25speakerA_bag.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d25speakerA_bag.wav
# Error loading file
# L2d11speaker1_well.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d11speaker1_well.wav
# Error loading file
# L2d22speaker1_ride1.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d22speaker1_ride1.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d55speakerA_door.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d55speakerA_door.wav
# Error loading file
# L2d41speakerA_waist.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d41speakerA_waist.wav
# Error loading file
# L2d21speaker1_waist.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d21speaker1_waist.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d19speakerA_write.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d19speakerA_write.wav
# Error loading file
# L2d32speakerA_cake.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d32speakerA_cake.wav
# Error loading file
# L2d37speaker1_pick2.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d37speaker1_pick2.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d14speaker1_band.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d14speaker1_band.wav
# Error loading file
# L2d58speaker1_door.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d58speaker1_door.wav
# Error loading file
# L2d49speakerA_back.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d49speakerA_back.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d29speaker1_gem.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d29speaker1_gem.wav
# Error loading file
# L2d55speaker1_lock.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d55speaker1_lock.wav
# Error loading file
# L2d47speaker1_lake.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d47speaker1_lake.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d58speakerA_pick2.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d58speakerA_pick2.wav
# Error loading file
# L2d25speaker1_shape.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d25speaker1_shape.wav
# Error loading file
# L2d59speakerA_door.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d59speakerA_door.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d2speakerA_tan.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d2speakerA_tan.wav
# Error loading file
# L2d49speakerA_peas.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d49speakerA_peas.wav
# Error loading file
# L2d12speakerA_pick2.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d12speakerA_pick2.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d11speakerA_coat.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d11speakerA_coat.wav
# Error loading file
# L2d29speakerA_eyes.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d29speakerA_eyes.wav
# Error loading file
# L2d57speakerA_brake.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d57speakerA_brake.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d11speakerA_can.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d11speakerA_can.wav
# Error loading file
# L2d40speaker1_ken.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d40speaker1_ken.wav
# Error loading file
# L2d43speaker1_cart.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d43speaker1_cart.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d28speakerA_gem.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d28speakerA_gem.wav
# Error loading file
# L2d41speakerA_lake.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d41speakerA_lake.wav
# Error loading file
# L2d46speaker1_nod.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d46speaker1_nod.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d55speakerA_bend.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d55speakerA_bend.wav
# Error loading file
# L2d48speaker1_gem.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d48speaker1_gem.wav
# Error loading file
# L2d56speaker1_code.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d56speaker1_code.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d23speakerA_brick.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d23speakerA_brick.wav
# Error loading file
# L2d25speaker1_brick.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d25speaker1_brick.wav
# Error loading file
# L2d51speakerA_peace.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d51speakerA_peace.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d43speaker1_can.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d43speaker1_can.wav
# Error loading file
# L2d11speaker1_lock.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d11speaker1_lock.wav
# Error loading file
# L2d47speaker1_x.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d47speaker1_x.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d12speaker1_robe.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d12speaker1_robe.wav
# Error loading file
# L2d27speakerA_ken.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d27speakerA_ken.wav
# Error loading file
# L2d1speaker1_eggs.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d1speaker1_eggs.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d26speaker1_ten.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d26speaker1_ten.wav
# Error loading file
# L2d15speaker1_log.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d15speaker1_log.wav
# Error loading file
# L2d14speaker1_gem.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d14speaker1_gem.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d6speaker1_lake.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d6speaker1_lake.wav
# Error loading file
# L2d29speaker1_chain.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d29speaker1_chain.wav
# Error loading file
# L2d15speaker1_door.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d15speaker1_door.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d28speaker1_jam.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d28speaker1_jam.wav
# Error loading file
# L2d8speakerA_banana.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d8speakerA_banana.wav
# Error loading file
# L2d19speakerA_ride1.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d19speakerA_ride1.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d14speaker1_ken.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d14speaker1_ken.wav
# Error loading file
# L2d22speakerA_coat.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d22speakerA_coat.wav
# Error loading file
# L2d4speaker1_pick2.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d4speaker1_pick2.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d35speakerA_seed.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d35speakerA_seed.wav
# Error loading file
# L2d39speaker1_can.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d39speaker1_can.wav
# Error loading file
# L2d55speaker1_kick.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d55speaker1_kick.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d23speakerA_west.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d23speakerA_west.wav
# Error loading file
# L2d3speaker1_pick2.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d3speaker1_pick2.wav
# Error loading file
# L2d10speaker1_kick.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d10speaker1_kick.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d15speaker1_eyes.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d15speaker1_eyes.wav
# Error loading file
# L2d51speakerA_pen.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d51speakerA_pen.wav
# Error loading file
# L2d37speaker1_bag.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d37speaker1_bag.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d40speakerA_waist.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d40speakerA_waist.wav
# Error loading file
# L2d42speaker1_kick.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d42speaker1_kick.wav
# Error loading file
# L2d38speaker1_pan.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d38speaker1_pan.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d12speakerA_jam.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d12speakerA_jam.wav
# Error loading file
# L2d7speaker1_seed.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d7speaker1_seed.wav
# Error loading file
# L2d3speakerA_ten.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d3speakerA_ten.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d11speaker1_jam.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d11speaker1_jam.wav
# Error loading file
# L2d47speakerA_robe.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d47speakerA_robe.wav
# Error loading file
# L2d1speaker1_door.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d1speaker1_door.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d56speaker1_eyes.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d56speaker1_eyes.wav
# Error loading file
# L2d1speakerA_peace.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d1speakerA_peace.wav
# Error loading file
# L2d16speakerA_knot.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d16speakerA_knot.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d31speakerA_bag.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d31speakerA_bag.wav
# Error loading file
# L2d17speakerA_door.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d17speakerA_door.wav
# Error loading file
# L2d12speakerA_rope.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d12speakerA_rope.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d16speaker1_eggs.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d16speaker1_eggs.wav
# Error loading file
# L2d34speakerA_tan.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d34speakerA_tan.wav
# Error loading file
# L2d55speakerA_bag.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d55speakerA_bag.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d17speaker1_can.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d17speaker1_can.wav
# Error loading file
# L2d17speakerA_whale.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d17speakerA_whale.wav
# Error loading file
# L2d25speaker1_can.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d25speaker1_can.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d51speakerA_seat.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d51speakerA_seat.wav
# Error loading file
# L2d57speakerA_cake.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d57speakerA_cake.wav
# Error loading file
# L2d46speaker1_waist.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d46speaker1_waist.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d49speakerA_knot.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d49speakerA_knot.wav
# Error loading file
# L2d5speakerA_robe.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d5speakerA_robe.wav
# Error loading file
# L2d47speakerA_seat.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d47speakerA_seat.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d4speaker1_card.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d4speaker1_card.wav
# Error loading file
# L2d31speaker1_jam.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d31speaker1_jam.wav
# Error loading file
# L2d25speaker1_kick.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d25speaker1_kick.wav
# ...
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d36speakerA_ten.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d36speakerA_ten.wav
# Error loading file
# L2d33speakerA_cart.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d33speakerA_cart.wav
# Error loading file
# L2d6speakerA_card.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d6speakerA_card.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d44speakerA_coat.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d44speakerA_coat.wav
# Error loading file
# L2d15speaker1_waist.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d15speaker1_waist.wav
# Error loading file
# L2d39speaker1_brick.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d39speaker1_brick.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d51speaker1_gem.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d51speaker1_gem.wav
# Error loading file
# L2d39speaker1_cake.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d39speaker1_cake.wav
# Error loading file
# L2d22speakerA_pan.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d22speakerA_pan.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d30speakerA_seat.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d30speakerA_seat.wav
# Error loading file
# L2d6speaker1_ship.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d6speaker1_ship.wav
# Error loading file
# L2d43speakerA_lick.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d43speakerA_lick.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d3speakerA_whale.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d3speakerA_whale.wav
# Error loading file
# L2d5speakerA_write.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d5speakerA_write.wav
# Error loading file
# L2d47speaker1_gem.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d47speaker1_gem.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d7speaker1_chin.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d7speaker1_chin.wav
# Error loading file
# L2d5speakerA_coat.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d5speakerA_coat.wav
# Error loading file
# L2d17speaker1_robe.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d17speaker1_robe.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d3speakerA_write.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d3speakerA_write.wav
# Error loading file
# L2d32speakerA_chin.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d32speakerA_chin.wav
# Error loading file
# L2d18speaker1_x.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d18speaker1_x.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d48speakerA_shape.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d48speakerA_shape.wav
# Error loading file
# L2d18speakerA_band.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d18speakerA_band.wav
# Error loading file
# L2d15speaker1_lake.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d15speaker1_lake.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d57speaker1_rope.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d57speaker1_rope.wav
# Error loading file
# L2d18speaker1_log.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d18speaker1_log.wav
# Error loading file
# L2d8speakerA_code.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d8speakerA_code.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d39speakerA_bag.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d39speakerA_bag.wav
# Error loading file
# L2d2speaker1_rope.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d2speaker1_rope.wav
# Error loading file
# L2d39speaker1_banana.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d39speaker1_banana.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d3speaker1_pen.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d3speaker1_pen.wav
# Error loading file
# L2d53speakerA_pan.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d53speakerA_pan.wav
# Error loading file
# L2d6speakerA_lock.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d6speakerA_lock.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d19speaker1_peace.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d19speaker1_peace.wav
# Error loading file
# L2d26speakerA_knot.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d26speakerA_knot.wav
# Error loading file
# L2d49speakerA_lake.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d49speakerA_lake.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d38speakerA_card.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d38speakerA_card.wav
# Error loading file
# L2d20speakerA_bag.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d20speakerA_bag.wav
# Error loading file
# L2d10speaker1_cake.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d10speaker1_cake.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d17speakerA_well.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d17speakerA_well.wav
# Error loading file
# L2d34speaker1_jam.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d34speaker1_jam.wav
# Error loading file
# L2d43speakerA_peace.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d43speakerA_peace.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Error loading file
# L2d55speakerA_can.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d55speakerA_can.wav
# Error loading file
# L2d43speakerA_ice.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d43speakerA_ice.wav
# Error loading file
# L2d5speaker1_pig.wav
# /home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper/L2d5speaker1_pig.wav
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /home/cogsci-lasrlab/.local/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")

# %%
# load audio and pad/trim it to fit 30 seconds
audio = whisper.load_audio('')
audio = whisper.pad_or_trim(audio)
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/whisper/audio.py in load_audio(file, sr)
#      57     try:
# ---> 58         out = run(cmd, capture_output=True, check=True).stdout
#      59     except CalledProcessError as e:
#
# /usr/lib/python3.10/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     525         if check and retcode:
# --> 526             raise CalledProcessError(retcode, process.args,
#     527                                      output=stdout, stderr=stderr)
#
# CalledProcessError: Command '['ffmpeg', '-nostdin', '-threads', '0', '-i', '', '-f', 's16le', '-ac', '1', '-acodec', 'pcm_s16le', '-ar', '16000', '-']' returned non-zero exit status 1.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_237865/159919710.py in <module>
#       1 # load audio and pad/trim it to fit 30 seconds
# ----> 2 audio = whisper.load_audio('')
#       3 audio = whisper.pad_or_trim(audio)
#
# ~/.local/lib/python3.10/site-packages/whisper/audio.py in load_audio(file, sr)
#      58         out = run(cmd, capture_output=True, check=True).stdout
#      59     except CalledProcessError as e:
# ---> 60         raise RuntimeError(f"Failed to load audio: {e.stderr.decode()}") from e
#      61
#      62     return np.frombuffer(out, np.int16).flatten().astype(np.float32) / 32768.0
#
# RuntimeError: Failed to load audio: ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# : No such file or directory

# %%
# make log-Mel spectrogram and move to the same device as the model
mel = whisper.log_mel_spectrogram(audio,n_mels=melsforthismodel).to(model.device)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_675724/3040389662.py in <module>
#       1 # make log-Mel spectrogram and move to the same device as the model
# ----> 2 mel = whisper.log_mel_spectrogram(audio,n_mels=melsforthismodel).to(model.device)
#
# NameError: name 'audio' is not defined

# %%
# detect the spoken language
_, probs = model.detect_language(mel)
print(f"Detected language: {max(probs, key=probs.get)}")
detectedlanguage = max(probs, key=probs.get)
print(f"Detected language: {detectedlanguage}")

# %%
# decode the audio
options = whisper.DecodingOptions(language="en", fp16 = False)
result = whisper.decode(model, mel, options)

# %%
# print the recognized text
print(result.text)

# %%
import os
import whisper  # Assuming this is your audio processing library

def list_files_in_folder(folder_path):
    if os.path.isdir(folder_path):
        files = os.listdir(folder_path)
        output_file_path = f"{folder_path.rstrip('/').replace('/', '_')}{runthismodel}_output.txt"
        print(f"Output_file_path for fcn list_files_in_folder is {output_file_path}")
        # Open the output file for writing
        with open(output_file_path, 'w') as f:
            # Write header to the file
            f.write(f"{'File':<32}{'Actual':<15}{'Predicted'}\n")
            f.write("="*70 + '\n')  # Separator line

            progress=0
            for file_name in files:
                if('.mp3' in file_name or '.wav' in file_name):
                    # Load model outside the loop to avoid reloading it for each file
                    model = whisper.load_model(runthismodel) #("base")
                    audio = whisper.load_audio(os.path.join(folder_path, file_name))
                    audio = whisper.pad_or_trim(audio)
                    mel = whisper.log_mel_spectrogram(audio,n_mels=melsforthismodel).to(model.device)
                    options = whisper.DecodingOptions(language="en", fp16=False) # what if unset to en?
                    result = whisper.decode(model, mel, options)

                    # new bit of code to see if I can detect
##                    _, probs = model.detect_language(mel)
##                    detectedlanguage = max(probs, key=probs.get)
##                    print(f"Detected language: {detectedlanguage}")

##                    # Extract the actual word from the file name
##                    actual_word = file_name[19:-4]

                    # Write formatted output to the file
                    ##f.write(f"{file_name:<32}{result.text}{' '}{detectedlanguage}\n")
                    f.write(f"{file_name:<32}{result.text}\n")

                    # Mirror to cmd line; remove \n so it doesn't double-space
                    print(f"{file_name:<32}{result.text}")
                    progress=progress+1
                    if (progress%50==0):
                        print(''.join(['\n', str(progress), " files completed so far\n"]))
                    
            print(''.join(['\nAll done. ', str(progress), ' files completed.']))
        print(f"Output written to {output_file_path}")

    else:
        print("The provided path for list_files_in_folder is not a directory.")

# %%
# Replace 'your_folder_path' with the actual path of the folder you want to open
#folder_path = 'EB21_KT1_MP3/'
folder_path = '/home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper' #"FANN SWS/" #"APstims/" #
list_files_in_folder(folder_path)
print(f"Folder path is {folder_path}")
# Out:
# Output_file_path for fcn list_files_in_folder is _home_cogsci-lasrlab_Desktop_LT2 Data_LT2 audio files for Whispersmall_output.txt
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_675724/3091416377.py in <module>
#       2 #folder_path = 'EB21_KT1_MP3/'
#       3 folder_path = '/home/cogsci-lasrlab/Desktop/LT2 Data/LT2 audio files for Whisper' #"FANN SWS/" #"APstims/" #
# ----> 4 list_files_in_folder(folder_path)
#       5 print(f"Folder path is {folder_path}")
#
# /tmp/ipykernel_675724/348428265.py in list_files_in_folder(folder_path)
#      22                     mel = whisper.log_mel_spectrogram(audio,n_mels=melsforthismodel).to(model.device)
#      23                     options = whisper.DecodingOptions(language="en", fp16=False) # what if unset to en?
# ---> 24                     result = whisper.decode(model, mel, options)
#      25
#      26                     # new bit of code to see if I can detect
#
# ~/.local/lib/python3.10/site-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# ~/.local/lib/python3.10/site-packages/whisper/decoding.py in decode(model, mel, options, **kwargs)
#     822         options = replace(options, **kwargs)
#     823
# --> 824     result = DecodingTask(model, options).run(mel)
#     825
#     826     return result[0] if single else result
#
# ~/.local/lib/python3.10/site-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# ~/.local/lib/python3.10/site-packages/whisper/decoding.py in run(self, mel)
#     716         n_audio: int = mel.shape[0]
#     717
# --> 718         audio_features: Tensor = self._get_audio_features(mel)  # encoder forward pass
#     719         tokens: Tensor = torch.tensor([self.initial_tokens]).repeat(n_audio, 1)
#     720
#
# ~/.local/lib/python3.10/site-packages/whisper/decoding.py in _get_audio_features(self, mel)
#     653             audio_features = mel
#     654         else:
# --> 655             audio_features = self.model.encoder(mel)
#     656
#     657         if audio_features.dtype != (
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# ~/.local/lib/python3.10/site-packages/whisper/model.py in forward(self, x)
#     191             the mel spectrogram of the audio
#     192         """
# --> 193         x = F.gelu(self.conv1(x))
#     194         x = F.gelu(self.conv2(x))
#     195         x = x.permute(0, 2, 1)
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     308
#     309     def forward(self, input: Tensor) -> Tensor:
# --> 310         return self._conv_forward(input, self.weight, self.bias)
#     311
#     312
#
# ~/.local/lib/python3.10/site-packages/whisper/model.py in _conv_forward(self, x, weight, bias)
#      55         self, x: Tensor, weight: Tensor, bias: Optional[Tensor]
#      56     ) -> Tensor:
# ---> 57         return super()._conv_forward(
#      58             x, weight.to(x.dtype), None if bias is None else bias.to(x.dtype)
#      59         )
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     304                             weight, bias, self.stride,
#     305                             _single(0), self.dilation, self.groups)
# --> 306         return F.conv1d(input, weight, bias, self.stride,
#     307                         self.padding, self.dilation, self.groups)
#     308
#
# RuntimeError: Given groups=1, weight of size [768, 80, 3], expected input[1, 128, 3000] to have 80 channels, but got 128 channels instead

# %%
#wav_to_mp3('EB21_researcher_KT1', 'EB21_researcher_KT1_MP3')
currenttime=datetime.datetime.now()
print(''.join(["Start time was ",str(starttime)]))
print(''.join(["End time is ",str(currenttime)]))
print(currenttime-starttime)
print('\n')

# %%
# Importing Wisper
import whisper

import datetime # to track how long this takes

starttime=datetime.datetime.now()
print(''.join(["Start time is",str(starttime)]))


# model details
runthismodel="large" # tried base.en. It seems to recognize it as a model BUT doesn't want to do the language detection or decoding options steps.
melsforthismodel=128 #need 128 for large model, 80 for smaller ones

# stimulus set: set "folder/" that contains sound files you want to do ASR on
soundfolder="audiofiles/APstims/"  ###"audiofiles/VRVT/mels100x34reg/"
# Loading the Model
model = whisper.load_model(runthismodel) #("base") # let's see how "large" model does SC 12/27/23
# load audio and pad/trim it to fit 30 seconds
audio = whisper.load_audio("chick.mp3")
audio = whisper.pad_or_trim(audio)
# make log-Mel spectrogram and move to the same device as the model
mel = whisper.log_mel_spectrogram(audio,n_mels=melsforthismodel).to(model.device)
# detect the spoken language
_, probs = model.detect_language(mel)
print(f"Detected language: {max(probs, key=probs.get)}")
detectedlanguage = max(probs, key=probs.get)
print(f"Detected language: {detectedlanguage}")
# decode the audio
options = whisper.DecodingOptions(language="en", fp16 = False)
result = whisper.decode(model, mel, options)
# print the recognized text
print(result.text)
import os
import whisper  # Assuming this is your audio processing library

def list_files_in_folder(folder_path):
    if os.path.isdir(folder_path):
        files = os.listdir(folder_path)
        output_file_path = f"{folder_path.rstrip('/').replace('/', '_')}{runthismodel}_output.txt"
        print(f"Output_file_path for fcn list_files_in_folder is {output_file_path}")
        # Open the output file for writing
        with open(output_file_path, 'w') as f:
            # Write header to the file
            f.write(f"{'File':<32}{'Actual':<15}{'Predicted'}\n")
            f.write("="*70 + '\n')  # Separator line

            progress=0
            for file_name in files:
                if('.mp3' in file_name or '.wav' in file_name):
                    # Load model outside the loop to avoid reloading it for each file
                    model = whisper.load_model(runthismodel) #("base")
                    audio = whisper.load_audio(os.path.join(folder_path, file_name))
                    audio = whisper.pad_or_trim(audio)
                    mel = whisper.log_mel_spectrogram(audio,n_mels=melsforthismodel).to(model.device)
                    options = whisper.DecodingOptions(language="en", fp16=False) # what if unset to en?
                    result = whisper.decode(model, mel, options)

                    # new bit of code to see if I can detect
##                    _, probs = model.detect_language(mel)
##                    detectedlanguage = max(probs, key=probs.get)
##                    print(f"Detected language: {detectedlanguage}")

##                    # Extract the actual word from the file name
##                    actual_word = file_name[19:-4]

                    # Write formatted output to the file
                    ##f.write(f"{file_name:<32}{result.text}{' '}{detectedlanguage}\n")
                    f.write(f"{file_name:<32}{result.text}\n")

                    # Mirror to cmd line; remove \n so it doesn't double-space
                    print(f"{file_name:<32}{result.text}")
                    progress=progress+1
                    if (progress%50==0):
                        print(''.join(['\n', str(progress), " files completed so far\n"]))
                    
            print(''.join(['\nAll done. ', str(progress), ' files completed.']))
        print(f"Output written to {output_file_path}")

    else:
        print("The provided path for list_files_in_folder is not a directory.")
# Replace 'your_folder_path' with the actual path of the folder you want to open
#folder_path = 'EB21_KT1_MP3/'
folder_path = '/Users/cogsci-lasrlab1/Desktop/Wisper_Work/allKT1files/lab_summerFall_2023_ppts' #"FANN SWS/" #"APstims/" #
list_files_in_folder(folder_path)
print(f"Folder path is {folder_path}")

# %%
#wav_to_mp3('EB21_researcher_KT1', 'EB21_researcher_KT1_MP3')
currenttime=datetime.datetime.now()
print(''.join(["Start time was ",str(starttime)]))
print(''.join(["End time is ",str(currenttime)]))
print(currenttime-starttime)
print('\n')
